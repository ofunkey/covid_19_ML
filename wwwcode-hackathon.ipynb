# %% [markdown]
# # Problem Statement
# Create an standardized index to catagorize the risk level of covid-19 spread in communities. Based on the paper [A COVID-19 Reopening Readiness Index: The Key to Opening up the Economy](https://www.medrxiv.org/content/10.1101/2020.05.22.20110577v2.full.pdf) found in [Corid-19 Search](https://cord19.aws/)

# %% [markdown]
# <hr>
# <p>Use the following indicators to determine a composite index</p>
#
# - mortality
# - hospitalizations
# - testing capacity
# - number of infections
# - infection rate
#
# <hr>

# %% [markdown]
# ### Datasets used
#
# <p>[The COVID Tracking Project, States](https://covidtracking.com/data/download)</p>
#
# **AWS Data Exchange: Rearc USA Hospital Beds - COVID-19 | Definitive Healthcare**
# <p>This dataset is intended to be used as a baseline for understanding the typical bed capacity and average yearly bed utilization of hospitals reporting such information. The date of last update received from each hospital may be varied. While the dataset is not updated in real-time, this information is critical for understanding the impact of a high utilization event, like COVID-19.<p>

# %% [markdown]
# ### FIPS
# Information about FIPS codes: [FIPS Codes](https://www.census.gov/library/reference/code-lists/ansi.html#par_textimage_3)

# %% [markdown]
# ### Datasets reviewed, but not used
# <p>but may be able to use in the future</p>
#
# **Data from John Hopkins Whiting School of Engineering** <br>
# Novel Coronavirus (COVID-19) Cases, provided by JHU CSSE<br>
# URL: [CSSEGISandData](https://github.com/CSSEGISandData/COVID-19)

# %% [markdown]
# <hr>
#
# **The COVID Tracking Project**<br>
# URL: [US data](https://covidtracking.com/data/download)
#
# We are using the state data. Deprecated variables are:
# * checkTimeEt
# * commercialScore
# * dateChecked
# * dateModified
# * grade
# * hash
# * hospitalized
# * negativeIncrease
# * negativeRegularScore
# * negativeScore
# * posNeg
# * positiveScore
# * score
# * total
#
# **Metadata**
#
# | variable | type | description | Nulls? |
# |:-|:-|:-|:-|
# | dataQualityGrade | string | The COVID Tracking Project grade of the completeness of the data reporting by a state. | No |
# | date | integer | Date on which data was collected by The COVID Tracking Project. | No |
# | death | integer | Total fatalities with confirmed OR probable COVID-19 case diagnosis (per the expanded [CSTE case definition](https://cdn.ymaws.com/www.cste.org/resource/resmgr/2020ps/Interim-20-ID-01_COVID-19.pdf) of April 5th, 2020 [approved by the CDC](https://wwwn.cdc.gov/nndss/conditions/coronavirus-disease-2019-covid-19/case-definition/2020/)). In states where the information is available, it only tracks fatalities with confirmed OR probable COVID-19 case diagnosis where COVID-19 is an underlying cause of death according to the death certificate based on [WHO guidelines](https://www.who.int/classifications/icd/Guidelines_Cause_of_Death_COVID-19.pdf?ua=1). | Yes |
# | deathConfirmed | integer | Total fatalities with confirmed COVID-19 case diagnosis (per the expanded [CSTE case definition](https://cdn.ymaws.com/www.cste.org/resource/resmgr/2020ps/Interim-20-ID-01_COVID-19.pdf) of April 5th, 2020 [approved by the CDC](https://wwwn.cdc.gov/nndss/conditions/coronavirus-disease-2019-covid-19/case-definition/2020/)). In states where the information is available, it only tracks fatalities with confirmed COVID-19 case diagnosis where COVID-19 is an underlying cause of death according to the death certificate based on [WHO guidelines](https://www.who.int/classifications/icd/Guidelines_Cause_of_Death_COVID-19.pdf?ua=1). | Yes |
# | deathIncrease | integer | Daily difference in death | Yes |
# | deathProbable | integer | Total fatalities with probable COVID-19 case diagnosis (per the expanded [CSTE case definition](https://cdn.ymaws.com/www.cste.org/resource/resmgr/2020ps/Interim-20-ID-01_COVID-19.pdf) of April 5th, 2020 [approved by the CDC](https://wwwn.cdc.gov/nndss/conditions/coronavirus-disease-2019-covid-19/case-definition/2020/). In states where the information is available, it only tracks fatalities with probable COVID-19 case diagnosis where COVID-19 is an underlying cause of death according to the death certificate based on [WHO guidelines](https://www.who.int/classifications/icd/Guidelines_Cause_of_Death_COVID-19.pdf?ua=1). | Yes |
# | fips | integer | Federal Information Processing Standards (FIPS) code for the state or territory. | Yes |
# | hospitalizedCumulative | integer | Total number of individuals who have ever been hospitalized with COVID-19. Definitions vary by state / territory. Where possible, we report hospitalizations with confirmed or probable COVID-19 cases per the expanded [CSTE case definition](https://cdn.ymaws.com/www.cste.org/resource/resmgr/2020ps/Interim-20-ID-01_COVID-19.pdf) of April 5th, 2020 [approved by the CDC](https://wwwn.cdc.gov/nndss/conditions/coronavirus-disease-2019-covid-19/case-definition/2020/). | No |
# | hospitalizedCurrently | integer | Individuals who are currently hospitalized with COVID-19. Definitions vary by state / territory. Where possible, we report hospitalizations with confirmed or probable COVID-19 cases per the expanded [CSTE case definition](https://cdn.ymaws.com/www.cste.org/resource/resmgr/2020ps/Interim-20-ID-01_COVID-19.pdf) of April 5th, 2020 [approved by the CDC](https://wwwn.cdc.gov/nndss/conditions/coronavirus-disease-2019-covid-19/case-definition/2020/). | Yes |
# | hospitalizedIncrease | integer | Daily difference in hospitalized | Yes |
# | inIcuCumulative | integer | Total number of individuals who have ever been hospitalized in the Intensive Care Unit with COVID-19. Definitions vary by state / territory. Where possible, we report patients in the ICU with confirmed or probable COVID-19 cases per the expanded [CSTE case definition](https://cdn.ymaws.com/www.cste.org/resource/resmgr/2020ps/Interim-20-ID-01_COVID-19.pdf) of April 5th, 2020 [approved by the CDC](https://wwwn.cdc.gov/nndss/conditions/coronavirus-disease-2019-covid-19/case-definition/2020/). | Yes |
# | inIcuCurrently | integer | Individuals who are currently hospitalized in the Intensive Care Unit with COVID-19. Definitions vary by state / territory. Where possible, we report patients in the ICU with confirmed or probable COVID-19 cases per the expanded [CSTE case definition](https://cdn.ymaws.com/www.cste.org/resource/resmgr/2020ps/Interim-20-ID-01_COVID-19.pdf) of April 5th, 2020 [approved by the CDC](https://wwwn.cdc.gov/nndss/conditions/coronavirus-disease-2019-covid-19/case-definition/2020/). | Yes |
# | lastUpdateEt | string | Date and time in Eastern time the state or territory last updated the data. | No |
# | negative | integer | Individuals with a completed viral test that returned a negative result. For states / territories that do not report this number directly, we compute it using one of several methods, depending on which data points the state provides. | Yes |
# | negativeTestsViral | integer | Completed viral tests that returned negative results. | Yes |
# | onVentilatorCumulative | integer | Total number of individuals who have ever been hospitalized under advanced ventilation with COVID-19. Definitions vary by state / territory. Where possible, we report patients on ventilation with confirmed or probable COVID-19 cases per the expanded [CSTE case definition](https://cdn.ymaws.com/www.cste.org/resource/resmgr/2020ps/Interim-20-ID-01_COVID-19.pdf) of April 5th, 2020 [approved by the CDC](https://wwwn.cdc.gov/nndss/conditions/coronavirus-disease-2019-covid-19/case-definition/2020/). | Yes |
# | onVentilatorCurrently | integer | Individuals who are currently hospitalized under advanced ventilation with COVID-19. Definitions vary by state / territory. Where possible, we report patients on ventilation with confirmed or probable COVID-19 cases per the expanded [CSTE case definition](https://cdn.ymaws.com/www.cste.org/resource/resmgr/2020ps/Interim-20-ID-01_COVID-19.pdf) of April 5th, 2020 [approved by the CDC](https://wwwn.cdc.gov/nndss/conditions/coronavirus-disease-2019-covid-19/case-definition/2020/). | Yes |
# | pending | integer | Tests whose results have not yet been reported. | Yes |
# | positive | integer | Individuals with confirmed or probable COVID-19 per the expanded [CSTE case definition](https://cdn.ymaws.com/www.cste.org/resource/resmgr/2020ps/Interim-20-ID-01_COVID-19.pdf) of April 5th, 2020 [approved by the CDC](https://wwwn.cdc.gov/nndss/conditions/coronavirus-disease-2019-covid-19/case-definition/2020/). | Yes |
# | positiveCasesViral | integer | Individuals with a completed viral test that returned a positive result. | Yes |
# | positiveIncrease | integer | Increase in *positive* computed by subtracting the value of *positive* from the previous day from the value of *positive* for the current day. | Yes |
# | positiveTestsViral | integer | Completed viral tests that returned positive results. | Yes |
# | recovered | integer | Individuals who have recovered from COVID-19. Definitions vary by state / territory. | Yes |
# | state | string | Two-letter abbreviation for the state or territory. | No |
# | totalTestResults | integer | Where possible, we report total tests in units of people tested, rather than units of specimens tested. Currently computed by adding _positive_ and _negative_ values because some states do not report totals and to work around different reporting cadences for cases and tests. | Yes |
# | totalTestResultsIncrease | integer | Daily Difference in totalTestResults | Yes |
# | totalTestsViral | integer | Completed viral tests. | Yes |

# %%
import pandas as pd
import numpy as np
import datetime
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import matplotlib.pyplot as plt # matplotlib.pyplot plots data

# %matplotlib inline

# %%
pd.set_option('display.max_columns', None)

#daily numbers for each state, from COVID tracking
url_states = "https://api.covidtracking.com/v1/states/daily.csv"
df_states = pd.read_csv(url_states, error_bad_lines=False) 

# drop deprecated variables
df_states.drop(columns=['checkTimeEt','commercialScore','dateChecked','dateModified','grade',
               'hash','hospitalized','negativeIncrease','negativeRegularScore','negativeScore','posNeg','positiveScore',
               'score','total'], inplace=True)
df_states.head()
# Out:
#        date state  positive  negative  pending  hospitalizedCurrently  \
# 0  20200814    AK    4869.0  291060.0      NaN                   38.0
# 1  20200814    AL  106309.0  718675.0      NaN                 1376.0
# 2  20200814    AR   52392.0  536268.0      NaN                  466.0
# 3  20200814    AS       0.0    1396.0      NaN                    NaN
# 4  20200814    AZ  191721.0  875854.0      NaN                 1359.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                     NaN             NaN              NaN
# 1                 12456.0             NaN           1305.0
# 2                  3566.0             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                 20515.0           473.0              NaN
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered dataQualityGrade  \
# 0                    3.0                     NaN     1371.0                A
# 1                    NaN                   716.0    41523.0                B
# 2                  113.0                   466.0    45446.0                A
# 3                    NaN                     NaN        NaN                C
# 4                  324.0                     NaN    27029.0               A+
#
#       lastUpdateEt   death  totalTestsViral  positiveTestsViral  \
# 0  8/14/2020 00:00    27.0         295929.0              4698.0
# 1  8/14/2020 11:00  1893.0         820871.0                 NaN
# 2  8/14/2020 14:34   587.0         588660.0                 NaN
# 3   8/5/2020 00:00     0.0              NaN                 NaN
# 4  8/14/2020 00:00  4423.0        1066146.0                 NaN
#
#    negativeTestsViral  positiveCasesViral  deathConfirmed  deathProbable  \
# 0            290927.0              4869.0            27.0            NaN
# 1                 NaN            102196.0          1825.0           68.0
# 2            536268.0             52392.0             NaN            NaN
# 3                 NaN                 0.0             NaN            NaN
# 4                 NaN            190292.0          4169.0          254.0
#
#    totalTestEncountersViral  totalTestsPeopleViral  totalTestsAntibody  \
# 0                       NaN                    NaN                 NaN
# 1                       NaN                    NaN                 NaN
# 2                       NaN                    NaN                 NaN
# 3                       NaN                 1396.0                 NaN
# 4                       NaN                    NaN            248666.0
#
#    positiveTestsAntibody  negativeTestsAntibody  totalTestsPeopleAntibody  \
# 0                    NaN                    NaN                       NaN
# 1                    NaN                    NaN                       NaN
# 2                    NaN                    NaN                       NaN
# 3                    NaN                    NaN                       NaN
# 4                    NaN                    NaN                       NaN
#
#    positiveTestsPeopleAntibody  negativeTestsPeopleAntibody  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    totalTestsPeopleAntigen  positiveTestsPeopleAntigen  totalTestsAntigen  \
# 0                      NaN                         NaN                NaN
# 1                      NaN                         NaN                NaN
# 2                      NaN                         NaN             1836.0
# 3                      NaN                         NaN                NaN
# 4                      NaN                         NaN                NaN
#
#    positiveTestsAntigen  fips  positiveIncrease  totalTestResults  \
# 0                   NaN     2               119          295929.0
# 1                   NaN     1               752          824984.0
# 2                   NaN     5               626          588660.0
# 3                   NaN    60                 0            1396.0
# 4                   NaN     4               927         1067575.0
#
#    totalTestResultsIncrease  deathIncrease  hospitalizedIncrease
# 0                      1876              0                     0
# 1                     22422              3                     0
# 2                      5180              5                     0
# 3                         0              0                     0
# 4                      9397             40                    12

# %%
#number of rows and columns
df_states.shape
# Out:
# (9089, 39)

# %%
# check for null values
df_states.isnull().sum()
# Out:
# date                              0
# state                             0
# positive                         15
# negative                        156
# pending                        7963
# hospitalizedCurrently          2624
# hospitalizedCumulative         4126
# inIcuCurrently                 5698
# inIcuCumulative                7732
# onVentilatorCurrently          6148
# onVentilatorCumulative         8607
# recovered                      3291
# dataQualityGrade               1101
# lastUpdateEt                    343
# death                           698
# totalTestsViral                5326
# positiveTestsViral             7858
# negativeTestsViral             7821
# positiveCasesViral             3101
# deathConfirmed                 5830
# deathProbable                  6949
# totalTestEncountersViral       8829
# totalTestsPeopleViral          5391
# totalTestsAntibody             7883
# positiveTestsAntibody          8207
# negativeTestsAntibody          8421
# totalTestsPeopleAntibody       8629
# positiveTestsPeopleAntibody    8794
# negativeTestsPeopleAntibody    8794
# totalTestsPeopleAntigen        9086
# positiveTestsPeopleAntigen     9088
# totalTestsAntigen              9060
# positiveTestsAntigen           9081
# fips                              0
# positiveIncrease                  0
# totalTestResults                  7
# totalTestResultsIncrease          0
# deathIncrease                     0
# hospitalizedIncrease              0
# dtype: int64

# %%
# drop variables with over 5k nulls
df_states.drop(columns=['pending','inIcuCurrently','inIcuCumulative','onVentilatorCurrently','onVentilatorCumulative',
               'totalTestsViral','positiveTestsViral','negativeTestsViral','deathConfirmed','deathProbable',
        'totalTestEncountersViral','totalTestsPeopleViral','totalTestsAntibody','positiveTestsAntibody',
        'negativeTestsAntibody','totalTestsPeopleAntigen','positiveTestsPeopleAntigen','totalTestsAntigen',
        'totalTestsPeopleAntibody','positiveTestsPeopleAntibody','negativeTestsPeopleAntibody',
        'positiveTestsAntigen'],
               inplace=True)
# check for null values
df_states.isnull().sum()
# Out:
# date                           0
# state                          0
# positive                      15
# negative                     156
# hospitalizedCurrently       2624
# hospitalizedCumulative      4126
# recovered                   3291
# dataQualityGrade            1101
# lastUpdateEt                 343
# death                        698
# positiveCasesViral          3101
# fips                           0
# positiveIncrease               0
# totalTestResults               7
# totalTestResultsIncrease       0
# deathIncrease                  0
# hospitalizedIncrease           0
# dtype: int64

# %%
df_states.drop(columns=['hospitalizedCumulative','recovered','dataQualityGrade','lastUpdateEt','positiveCasesViral',
        'positiveIncrease','totalTestResultsIncrease','deathIncrease','hospitalizedIncrease'],
               inplace=True)
# check for null values
df_states.isnull().sum()
# Out:
# date                        0
# state                       0
# positive                   15
# negative                  156
# hospitalizedCurrently    2624
# death                     698
# fips                        0
# totalTestResults            7
# dtype: int64

# %%
hist = df_states.plot.hist(figsize=(10,10),layout=(3,4))

# %%
 def plot_corr(df, size=11):
    """
    Function plots a graphical correlation matrix for each pair of columns in the dataframe. 
    Shows the relationship between features.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot

    Displays:
        matrix of correlation between columns.  
                                                0 ------------------>  1
                                                Expect a line running from top left to bottom right
    """

    corr = df.corr()    # data frame correlation function
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)   # color code the rectangles by correlation value
    plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')  # draw x tick marks
    plt.yticks(range(len(corr.columns)), corr.columns)  # draw y tick marks

# %%
plot_corr(df_states)

# %%
df_states.drop(columns=['negative'],inplace=True)

#drop records with no hospitalizations or deaths
df_states.dropna(subset=['hospitalizedCurrently'], inplace=True)
df_states.dropna(subset=['death'], inplace=True)

# %%
plot_corr(df_states)

# %%
#correlations
corr = df_states.corr()
corr.style.background_gradient(cmap="coolwarm")
# Out:
# <style  type="text/css" >
#     #T_0c426740_de94_11ea_978d_c4b301b74411row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row0_col1 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row0_col2 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row0_col3 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row0_col4 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row0_col5 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row1_col0 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row1_col2 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row1_col3 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row1_col4 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row1_col5 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row2_col1 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row2_col3 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row2_col5 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row3_col0 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row3_col1 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row3_col2 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row3_col4 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row3_col5 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row4_col0 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row5_col0 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row5_col1 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row5_col2 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row5_col3 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row5_col4 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_0c426740_de94_11ea_978d_c4b301b74411row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_0c426740_de94_11ea_978d_c4b301b74411" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >date</th>        <th class="col_heading level0 col1" >positive</th>        <th class="col_heading level0 col2" >hospitalizedCurrently</th>        <th class="col_heading level0 col3" >death</th>        <th class="col_heading level0 col4" >fips</th>        <th class="col_heading level0 col5" >totalTestResults</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0c426740_de94_11ea_978d_c4b301b74411level0_row0" class="row_heading level0 row0" >date</th>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row0_col1" class="data row0 col1" >0.307323</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row0_col2" class="data row0 col2" >-0.051941</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row0_col3" class="data row0 col3" >0.177579</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row0_col4" class="data row0 col4" >0.019827</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row0_col5" class="data row0 col5" >0.386774</td>
#             </tr>
#             <tr>
#                         <th id="T_0c426740_de94_11ea_978d_c4b301b74411level0_row1" class="row_heading level0 row1" >positive</th>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row1_col0" class="data row1 col0" >0.307323</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row1_col2" class="data row1 col2" >0.634823</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row1_col3" class="data row1 col3" >0.816221</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row1_col4" class="data row1 col4" >-0.095044</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row1_col5" class="data row1 col5" >0.900645</td>
#             </tr>
#             <tr>
#                         <th id="T_0c426740_de94_11ea_978d_c4b301b74411level0_row2" class="row_heading level0 row2" >hospitalizedCurrently</th>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row2_col0" class="data row2 col0" >-0.051941</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row2_col1" class="data row2 col1" >0.634823</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row2_col3" class="data row2 col3" >0.399712</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row2_col4" class="data row2 col4" >-0.108906</td>
#                         <td id="T_0c426740_de94_11ea_978d_c4b301b74411row2_col5" class="data row2 col5" >0.467306</td>
#             </tr>
#             <tr>

# %% [markdown]
# <hr>
#
# **AWS Data Exchange: Rearc USA Hospital Beds | Definitive Healthcare**<br>
# Download date: 8/14/2020<br>
# Revision ID: e74796dd4d22e56d1c037ed407378067

# %%
#AWS Data Exchange: Rearc USA Hospital Beds | Definitive Healthcare
#Download date: 8/14/2020
#Revision ID: e74796dd4d22e56d1c037ed407378067

df_hospital_beds = pd.read_csv("./data/usa-hospital-beds_dataset_usa-hospital-beds.csv")

# %%
df_hospital_beds.head()
# Out:
#             X          Y  OBJECTID  \
# 0 -112.066157  33.495498         1
# 1 -110.965885  32.181263         2
# 2 -119.779742  36.773323         3
# 3  -72.957610  41.284400         4
# 4  -75.606533  39.740206         5
#
#                                        HOSPITAL_NAME HOSPITAL_TYPE  \
# 0  Phoenix VA Health Care System (AKA Carl T Hayd...   VA Hospital
# 1             Southern Arizona VA Health Care System   VA Hospital
# 2           VA Central California Health Care System   VA Hospital
# 3  VA Connecticut Healthcare System - West Haven ...   VA Hospital
# 4                       Wilmington VA Medical Center   VA Hospital
#
#                HQ_ADDRESS HQ_ADDRESS1     HQ_CITY HQ_STATE  HQ_ZIP_CODE  \
# 0  650 E Indian School Rd         NaN     Phoenix       AZ        85012
# 1          3601 S 6th Ave         NaN      Tucson       AZ        85723
# 2      2615 E Clinton Ave         NaN      Fresno       CA        93703
# 3        950 Campbell Ave         NaN  West Haven       CT         6516
# 4       1601 Kirkwood Hwy         NaN  Wilmington       DE        19805
#
#   COUNTY_NAME   STATE_NAME  STATE_FIPS  CNTY_FIPS     FIPS  NUM_LICENSED_BEDS  \
# 0    Maricopa      Arizona         4.0       13.0   4013.0               62.0
# 1        Pima      Arizona         4.0       19.0   4019.0              295.0
# 2      Fresno   California         6.0       19.0   6019.0               54.0
# 3   New Haven  Connecticut         9.0        9.0   9009.0              216.0
# 4  New Castle     Delaware        10.0        3.0  10003.0               62.0
#
#    NUM_STAFFED_BEDS  NUM_ICU_BEDS  ADULT_ICU_BEDS  PEDI_ICU_BEDS  \
# 0              62.0             0               0            NaN
# 1             295.0             2               2            NaN
# 2              54.0             2               2            NaN
# 3             216.0             1               1            NaN
# 4              62.0             0               0            NaN
#
#    BED_UTILIZATION  Potential_Increase_In_Bed_Capac  AVG_VENTILATOR_USAGE
# 0              NaN                                0                     0
# 1              NaN                                0                     2
# 2              NaN                                0                     2
# 3              NaN                                0                     2
# 4              NaN                                0                     1

# %%
df_hospital_beds.shape
# Out:
# (6622, 23)

# %%
# check for null values
df_hospital_beds.isnull().sum()
# Out:
# X                                    18
# Y                                    18
# OBJECTID                              0
# HOSPITAL_NAME                         0
# HOSPITAL_TYPE                         0
# HQ_ADDRESS                            0
# HQ_ADDRESS1                        6254
# HQ_CITY                               0
# HQ_STATE                              0
# HQ_ZIP_CODE                           0
# COUNTY_NAME                          25
# STATE_NAME                           25
# STATE_FIPS                           25
# CNTY_FIPS                            25
# FIPS                                 25
# NUM_LICENSED_BEDS                   152
# NUM_STAFFED_BEDS                    240
# NUM_ICU_BEDS                          0
# ADULT_ICU_BEDS                        0
# PEDI_ICU_BEDS                       739
# BED_UTILIZATION                     714
# Potential_Increase_In_Bed_Capac       0
# AVG_VENTILATOR_USAGE                  0
# dtype: int64

# %%
df_hospital_beds.drop(columns=['X','Y','OBJECTID','HOSPITAL_NAME','HOSPITAL_TYPE','HQ_ADDRESS',
                              'HQ_ADDRESS1','HQ_CITY','HQ_STATE','HQ_ZIP_CODE','COUNTY_NAME',
                              'STATE_NAME','CNTY_FIPS','FIPS','NUM_STAFFED_BEDS',
                              'ADULT_ICU_BEDS','PEDI_ICU_BEDS','Potential_Increase_In_Bed_Capac',
                              'BED_UTILIZATION','AVG_VENTILATOR_USAGE'],inplace=True)

# %%
df_hospital_beds.head(30)
# Out:
#     STATE_FIPS  NUM_LICENSED_BEDS  NUM_ICU_BEDS
# 0          4.0               62.0             0
# 1          4.0              295.0             2
# 2          6.0               54.0             2
# 3          9.0              216.0             1
# 4         10.0               62.0             0
# 5         11.0              164.0             1
# 6         12.0              432.0             2
# 7         16.0               46.0             1
# 8         22.0              111.0             1
# 9         28.0              160.0            10
# 10        29.0               89.0             2
# 11        35.0              163.0             1
# 12        36.0               67.0             2
# 13        36.0              311.0             2
# 14        38.0               37.0             1
# 15        41.0                NaN             0
# 16        42.0              146.0             2
# 17         1.0               85.0             6
# 18         1.0              150.0            17
# 19         1.0               58.0             4
# 20         1.0               74.0             5
# 21         1.0               35.0             4
# 22         1.0               25.0             6
# 23         1.0               61.0             5
# 24         1.0               72.0             7
# 25         1.0              125.0             6
# 26         1.0              323.0            18
# 27         1.0              115.0            15
# 28         1.0               60.0             8
# 29         1.0               50.0             4

# %%
#replace NaN with 0
df_hospital_beds = df_hospital_beds.fillna(0)
df_hospital_beds
# Out:
#       STATE_FIPS  NUM_LICENSED_BEDS  NUM_ICU_BEDS
# 0            4.0               62.0             0
# 1            4.0              295.0             2
# 2            6.0               54.0             2
# 3            9.0              216.0             1
# 4           10.0               62.0             0
# ...          ...                ...           ...
# 6617        48.0                0.0             0
# 6618        42.0                0.0             0
# 6619        48.0                0.0             0
# 6620        48.0                0.0             0
# 6621        32.0                0.0             0
#
# [6622 rows x 3 columns]

# %%
#create a new dataframe using groupby
grouper = df_hospital_beds.groupby('STATE_FIPS')
df_total_hospital_beds = grouper['NUM_LICENSED_BEDS'].sum().to_frame(name = 'TOTAL_NUM_LICENSED_BEDS').reset_index()

#drop the null state_fips row
df_total_hospital_beds = df_total_hospital_beds[df_total_hospital_beds['STATE_FIPS'] != 0]

# %%
#create a new dataframe using groupby
grouper = df_hospital_beds.groupby('STATE_FIPS')
df_total_icu_beds = grouper['NUM_ICU_BEDS'].sum().to_frame(name = 'TOTAL_NUM_ICU_BEDS').reset_index()

#drop the null state_fips row
df_total_icu_beds = df_total_icu_beds[df_total_icu_beds['STATE_FIPS'] != 0]

# %%
df_states = df_states.join(df_total_hospital_beds.set_index(['STATE_FIPS'], verify_integrity=True ),on=['fips'], how='left')

# %%
df_states = df_states.join(df_total_icu_beds.set_index(['STATE_FIPS'], verify_integrity=True ),on=['fips'], how='left')

# %%
#sort by states and date
df_states = df_states.sort_values(["fips", "date"], ascending = (True, False))
df_states.head()
# Out:
#          date state  positive  hospitalizedCurrently   death  fips  \
# 1    20200814    AL  106309.0                 1376.0  1893.0     1
# 57   20200813    AL  105557.0                 1365.0  1890.0     1
# 113  20200812    AL  104786.0                 1372.0  1882.0     1
# 169  20200811    AL  103851.0                 1506.0  1847.0     1
# 225  20200810    AL  103020.0                 1528.0  1797.0     1
#
#      totalTestResults  TOTAL_NUM_LICENSED_BEDS  TOTAL_NUM_ICU_BEDS
# 1            824984.0                  18611.0              1637.0
# 57           802562.0                  18611.0              1637.0
# 113          795771.0                  18611.0              1637.0
# 169          783689.0                  18611.0              1637.0
# 225          780567.0                  18611.0              1637.0

# %%
# check datatypes
print('Check datatypes:')
display(df_states.dtypes)
# Out:
# Check datatypes:
# date                         int64
# state                       object
# positive                   float64
# hospitalizedCurrently      float64
# death                      float64
# fips                         int64
# totalTestResults           float64
# TOTAL_NUM_LICENSED_BEDS    float64
# TOTAL_NUM_ICU_BEDS         float64
# dtype: object

# %%
# check statistics of the features
df_states.describe()
# Out:
#                date       positive  hospitalizedCurrently         death  \
# count  6.461000e+03    6461.000000            6461.000000   6461.000000
# mean   2.020060e+07   46426.359697             963.553784   1977.381365
# std    1.301475e+02   80206.116187            1858.252235   3885.242788
# min    2.020032e+07      32.000000               0.000000      0.000000
# 25%    2.020051e+07    4442.000000              95.000000    113.000000
# 50%    2.020061e+07   17766.000000             386.000000    542.000000
# 75%    2.020072e+07   50684.000000             953.000000   1874.000000
# max    2.020081e+07  601075.000000           18825.000000  25232.000000
#
#               fips  totalTestResults  TOTAL_NUM_LICENSED_BEDS  \
# count  6461.000000      6.461000e+03              6362.000000
# mean     30.575917      5.074074e+05             18624.820340
# std      17.209706      9.133083e+05             18481.204854
# min       1.000000      1.510000e+02              1706.000000
# 25%      17.000000      7.417400e+04              4748.000000
# 50%      30.000000      2.060160e+05             15195.000000
# 75%      44.000000      5.511090e+05             22262.000000
# max      78.000000      9.556598e+06             83560.000000
#
#        TOTAL_NUM_ICU_BEDS
# count         6362.000000
# mean          1775.844074
# std           1849.605883
# min            151.000000
# 25%            516.000000
# 50%           1363.000000
# 75%           2170.000000
# max           8719.000000

# %% [markdown]
# ### Histograms

# %%
# plot histogram of positive
df_states.positive.hist(bins=5, figsize=(20,3))
plt.xlabel('positive')
plt.title('Histogram');

# %%
# plot histogram of death
df_states.death.hist(bins=5, figsize=(20,3))
plt.xlabel('death')
plt.title('Histogram');

# %%
# plot histogram of totalTestResults
df_states.totalTestResults.hist(bins=5, figsize=(20,3))
plt.xlabel('totalTestResults')
plt.title('Histogram');

# %%
# plot histogram of hospitalizedCurrently
df_states.hospitalizedCurrently.hist(bins=5, figsize=(20,3))
plt.xlabel('hospitalizedCurrently')
plt.title('Histogram');

# %% [markdown]
# ### Correlation
# Checking for correlation

# %%
df_states.plot(x='totalTestResults', y='positive', style='o')  
plt.title('totalTestResults vs positive')  
plt.xlabel('totalTestResults')  
plt.ylabel('positive')  
plt.show()

# %%
df_states.plot(x='totalTestResults', y='hospitalizedCurrently', style='o')  
plt.title('totalTestResults vs hospitalizedCurrently')  
plt.xlabel('totalTestResults')  
plt.ylabel('hospitalizedCurrently')  
plt.show()

# %%
df_states.plot(x='hospitalizedCurrently', y='death', style='o')  
plt.title('hospitalizedCurrently vs death')  
plt.xlabel('hospitalizedCurrently')  
plt.ylabel('death')  
plt.show()

# %%
#test for hospitalizedCurrently 
# split data into train test set into train and test in 70:30 ratio
df = df_states
# drop records without indicators
df.dropna(subset=['death','positive','hospitalizedCurrently','totalTestResults'], inplace=True)

y = df["hospitalizedCurrently"]
X = df.drop(['hospitalizedCurrently','state','TOTAL_NUM_LICENSED_BEDS','TOTAL_NUM_ICU_BEDS','date','fips'], axis=1)



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# %%
X_train.dtypes
# Out:
# positive            float64
# death               float64
# totalTestResults    float64
# dtype: object

# %%
y_train.dtypes
# Out:
# dtype('float64')

# %%
# Train and predict using linear regression
linear_reg = LinearRegression()
# Train with the train dataset
linear_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
coeff_df = pd.DataFrame(linear_reg.coef_, X_train.columns, columns=['Coefficient'])  
coeff_df
# Out:
#                   Coefficient
# positive             0.036640
# death               -0.224114
# totalTestResults    -0.001309

# %%
intercept_df = pd.Series(linear_reg.intercept_)
intercept_df
# Out:
# 0    359.72262
# dtype: float64

# %%
#test for totalTestResults 
# split data into train test set into train and test in 70:30 ratio
df = df_states
# drop records without indicators
df.dropna(subset=['death','positive','hospitalizedCurrently','totalTestResults'], inplace=True)

y = df["totalTestResults"]
X = df.drop(['totalTestResults','state','TOTAL_NUM_LICENSED_BEDS','TOTAL_NUM_ICU_BEDS','date','fips'], axis=1)



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# Train and predict using linear regression
linear_reg = LinearRegression()
# Train with the train dataset
linear_reg.fit(X_train, y_train)

coeff_df = pd.DataFrame(linear_reg.coef_, X_train.columns, columns=['Coefficient'])  
coeff_df
# Out:
#                        Coefficient
# positive                 13.799061
# hospitalizedCurrently  -103.960601
# death                   -54.279865

# %%
intercept_df = pd.Series(linear_reg.intercept_)
intercept_df
# Out:
# 0    72823.627018
# dtype: float64

# %%
#test for death 
# split data into train test set into train and test in 70:30 ratio
df = df_states
# drop records without indicators
df.dropna(subset=['death','positive','hospitalizedCurrently','totalTestResults'], inplace=True)

y = df["death"]
X = df.drop(['death','state','TOTAL_NUM_LICENSED_BEDS','TOTAL_NUM_ICU_BEDS','date','fips'], axis=1)



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# Train and predict using linear regression
linear_reg = LinearRegression()
# Train with the train dataset
linear_reg.fit(X_train, y_train)

coeff_df = pd.DataFrame(linear_reg.coef_, X_train.columns, columns=['Coefficient'])  
coeff_df
# Out:
#                        Coefficient
# positive                  0.066456
# hospitalizedCurrently    -0.608714
# totalTestResults         -0.001857

# %%
intercept_df = pd.Series(linear_reg.intercept_)
intercept_df
# Out:
# 0    410.484437
# dtype: float64

# %%
#test for positive 
# split data into train test set into train and test in 70:30 ratio
df = df_states
# drop records without indicators
df.dropna(subset=['death','positive','hospitalizedCurrently','totalTestResults'], inplace=True)

y = df["positive"]
X = df.drop(['positive','state','TOTAL_NUM_LICENSED_BEDS','TOTAL_NUM_ICU_BEDS','date','fips'], axis=1)



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# %%
# Train and predict using linear regression
linear_reg = LinearRegression()
# Train with the train dataset
linear_reg.fit(X_train, y_train)
coeff_df = pd.DataFrame(linear_reg.coef_, X_train.columns, columns=['Coefficient'])  
coeff_df
# Out:
#                        Coefficient
# hospitalizedCurrently    10.487302
# death                     7.003148
# totalTestResults          0.049746

# %%
# create 3-day rolling averages of cases, infection rate, mortality, hospitalization, 
# testing capacity and hospital rate (hospital_rate) and hospital rate using ICU beds (hospital_rate2)
for i in range(0,df_states.shape[0]-2):
  if(df_states.iloc[i,5] == df_states.iloc[i+1,5] and df_states.iloc[i+1,5] == df_states.iloc[i+2,5]):
    df_states.loc[df_states.index[i],'count'] = np.round(((df_states.iloc[i,2]+ df_states.iloc[i+1,2] +df_states.iloc[i+2,2])/3),2)
    df_states.loc[df_states.index[i],'testing_capacity'] = np.round(((df_states.iloc[i,6]+ df_states.iloc[i+1,6] +df_states.iloc[i+2,6])/3),2)
    df_states.loc[df_states.index[i],'mortality'] = np.round(((df_states.iloc[i,4]+ df_states.iloc[i+1,4] +df_states.iloc[i+2,4])/3),2)   
    df_states.loc[df_states.index[i],'hospitalization'] = np.round(((df_states.iloc[i,3]+ df_states.iloc[i+1,3] +df_states.iloc[i+2,3])/3),2)   
    if(df_states.iloc[i,6] != 0 and df_states.iloc[i+1,6] != 0 and df_states.iloc[i+2,6] != 0):
      df_states.loc[df_states.index[i],'infection_rate'] = np.round(df_states.loc[df_states.index[i],'count'] / df_states.loc[df_states.index[i],'testing_capacity'],2)
    else:
      df_states.loc[df_states.index[i],'infection_rate'] = 0  
    if(df_states.iloc[i,7] != 0 and df_states.iloc[i+1,7] != 0 and df_states.iloc[i+2,7] != 0):
      df_states.loc[df_states.index[i],'hospitalization_rate'] = np.round(df_states.loc[df_states.index[i],'hospitalization'] / df_states.loc[df_states.index[i],'TOTAL_NUM_LICENSED_BEDS'],2)
    else:
      df_states.loc[df_states.index[i],'hospitalization_rate'] = 0   
    if(df_states.iloc[i,8] != 0 and df_states.iloc[i+1,8] != 0 and df_states.iloc[i+2,8] != 0):
      df_states.loc[df_states.index[i],'hospitalization_rate2'] = np.round(df_states.loc[df_states.index[i],'hospitalization'] / df_states.loc[df_states.index[i],'TOTAL_NUM_ICU_BEDS'],2)
    else:
      df_states.loc[df_states.index[i],'hospitalization_rate2'] = 0 
  else: 
    df_states.loc[df_states.index[i],'count'] = 0
    df_states.loc[df_states.index[i],'testing_capacity'] = 0
    df_states.loc[df_states.index[i],'mortality'] = 0
    df_states.loc[df_states.index[i],'hospitalization'] = 0

# %%
#48 is Texas
df_states.loc[df_states['fips'] == 48].tail()
# Out:
#           date state  positive  hospitalizedCurrently  death  fips  \
# 7439  20200404    TX    6110.0                  196.0  105.0    48
# 7495  20200403    TX    5330.0                  196.0   90.0    48
# 7551  20200402    TX    4669.0                  196.0   70.0    48
# 7607  20200401    TX    3997.0                  196.0   58.0    48
# 7663  20200331    TX    3266.0                  196.0   41.0    48
#
#       totalTestResults  TOTAL_NUM_LICENSED_BEDS  TOTAL_NUM_ICU_BEDS    count  \
# 7439           63751.0                  82125.0              8719.0  5369.67
# 7495           55764.0                  82125.0              8719.0  4665.33
# 7551           50679.0                  82125.0              8719.0  3977.33
# 7607           47857.0                  82125.0              8719.0     0.00
# 7663           42992.0                  82125.0              8719.0     0.00
#
#       testing_capacity  mortality  hospitalization  infection_rate  \
# 7439          56731.33      88.33            196.0            0.09
# 7495          51433.33      72.67            196.0            0.09
# 7551          47176.00      56.33            196.0            0.08
# 7607              0.00       0.00              0.0             NaN
# 7663              0.00       0.00              0.0             NaN
#
#       hospitalization_rate  hospitalization_rate2
# 7439                   0.0                   0.02
# 7495                   0.0                   0.02
# 7551                   0.0                   0.02
# 7607                   NaN                    NaN
# 7663                   NaN                    NaN

# %%
df_states.loc[df_states['fips'] == 48].head()
# Out:
#          date state  positive  hospitalizedCurrently   death  fips  \
# 47   20200814    TX  520593.0                 6632.0  9602.0    48
# 103  20200813    TX  513575.0                 6879.0  9289.0    48
# 159  20200812    TX  506820.0                 7028.0  9034.0    48
# 215  20200811    TX  500620.0                 7216.0  8710.0    48
# 271  20200810    TX  490817.0                 7304.0  8490.0    48
#
#      totalTestResults  TOTAL_NUM_LICENSED_BEDS  TOTAL_NUM_ICU_BEDS      count  \
# 47          4282041.0                  82125.0              8719.0  513662.67
# 103         4230763.0                  82125.0              8719.0  507005.00
# 159         4106360.0                  82125.0              8719.0  499419.00
# 215         4088863.0                  82125.0              8719.0  492599.67
# 271         4073661.0                  82125.0              8719.0  486220.67
#
#      testing_capacity  mortality  hospitalization  infection_rate  \
# 47         4206388.00    9308.33          6846.33            0.12
# 103        4141995.33    9011.00          7041.00            0.12
# 159        4089628.00    8744.67          7182.67            0.12
# 215        4062796.00    8553.00          7319.00            0.12
# 271        4037394.00    8430.67          7537.67            0.12
#
#      hospitalization_rate  hospitalization_rate2
# 47                   0.08                   0.79
# 103                  0.09                   0.81
# 159                  0.09                   0.82
# 215                  0.09                   0.84
# 271                  0.09                   0.86

# %%
#6 is California
df_states.loc[df_states['fips'] == 6].tail()
# Out:
#           date state  positive  hospitalizedCurrently  death  fips  \
# 7621  20200331    CA    7482.0                 1617.0  153.0     6
# 7677  20200330    CA    6447.0                 1432.0  133.0     6
# 7733  20200329    CA    5708.0                 1034.0  123.0     6
# 7789  20200328    CA    4643.0                 1034.0  101.0     6
# 7845  20200327    CA    3879.0                  746.0   78.0     6
#
#       totalTestResults  TOTAL_NUM_LICENSED_BEDS  TOTAL_NUM_ICU_BEDS    count  \
# 7621           29254.0                  83560.0              8691.0  6545.67
# 7677           26996.0                  83560.0              8691.0  5599.33
# 7733           26257.0                  83560.0              8691.0  4743.33
# 7789           25192.0                  83560.0              8691.0     0.00
# 7845           21259.0                  83560.0              8691.0     0.00
#
#       testing_capacity  mortality  hospitalization  infection_rate  \
# 7621          27502.33     136.33          1361.00            0.24
# 7677          26148.33     119.00          1166.67            0.21
# 7733          24236.00     100.67           938.00            0.20
# 7789              0.00       0.00             0.00             NaN
# 7845              0.00       0.00             0.00             NaN
#
#       hospitalization_rate  hospitalization_rate2
# 7621                  0.02                   0.16
# 7677                  0.01                   0.13
# 7733                  0.01                   0.11
# 7789                   NaN                    NaN
# 7845                   NaN                    NaN

# %%
#6 is California
df_states.loc[df_states['fips'] == 6].head()
# Out:
#          date state  positive  hospitalizedCurrently    death  fips  \
# 5    20200814    CA  601075.0                 6364.0  10996.0     6
# 61   20200813    CA  593141.0                 6424.0  10808.0     6
# 117  20200812    CA  586056.0                 6647.0  10648.0     6
# 173  20200811    CA  574411.0                 6759.0  10468.0     6
# 229  20200810    CA  561911.0                 6770.0  10359.0     6
#
#      totalTestResults  TOTAL_NUM_LICENSED_BEDS  TOTAL_NUM_ICU_BEDS      count  \
# 5           9556598.0                  83560.0              8691.0  593424.00
# 61          9445493.0                  83560.0              8691.0  584536.00
# 117         9303467.0                  83560.0              8691.0  574126.00
# 173         9186279.0                  83560.0              8691.0  563494.00
# 229         8998353.0                  83560.0              8691.0  553952.67
#
#      testing_capacity  mortality  hospitalization  infection_rate  \
# 5          9435186.00   10817.33          6478.33            0.06
# 61         9311746.33   10641.33          6610.00            0.06
# 117        9162699.67   10491.67          6725.33            0.06
# 173        9003583.67   10373.33          6792.67            0.06
# 229        8843999.67   10280.33          6858.33            0.06
#
#      hospitalization_rate  hospitalization_rate2
# 5                    0.08                   0.75
# 61                   0.08                   0.76
# 117                  0.08                   0.77
# 173                  0.08                   0.78
# 229                  0.08                   0.79

# %%
plot_corr(df_states)

# %%
#find mins and maxes
grouped_df = df_states.groupby("fips")
maximums = grouped_df.max()
maximums = maximums.reset_index()
minimums = grouped_df.min()
minimums = minimums.reset_index()

# %%
maximums.drop(columns=['death','state','positive','hospitalizedCurrently','totalTestResults','TOTAL_NUM_LICENSED_BEDS',
                       'TOTAL_NUM_ICU_BEDS','date'],inplace=True)
minimums.drop(columns=['death','state','positive','hospitalizedCurrently','totalTestResults','TOTAL_NUM_LICENSED_BEDS',
                       'TOTAL_NUM_ICU_BEDS','date'],inplace=True)

# %%
maximums.rename(columns={'count':'count_max','testing_capacity':'testing_capacity_max','mortality':'mortality_max',
                          'hospitalization':'hospitalization_max','infection_rate':'infection_rate_max',
                         'hospitalization_rate':'hospitalization_rate_max',
                         'hospitalization_rate2':'hospitalization_rate2_max'}, 
                 inplace=True)
minimums.rename(columns={'count':'count_min','testing_capacity':'testing_capacity_min','mortality':'mortality_min',
                          'hospitalization':'hospitalization_min','infection_rate':'infection_rate_min',
                         'hospitalization_rate':'hospitalization_rate_min',
                         'hospitalization_rate2':'hospitalization_rate2_min'}, 
                 inplace=True)

# %%
#use 0 for nulls in hospital rates
maximums = maximums.fillna(0)
minimums = minimums.fillna(0)
maximums.head()
# Out:
#    fips  count_max  testing_capacity_max  mortality_max  hospitalization_max  \
# 0     1  105550.67             807772.33        1888.33              1598.33
# 1     2    4758.00             294188.00          27.00                44.67
# 2     4  190652.67            1056660.33        4384.33              3488.00
# 3     5   51757.33             581903.67         578.33               518.67
# 4     6  593424.00            9435186.00       10817.33              8820.00
#
#    infection_rate_max  hospitalization_rate_max  hospitalization_rate2_max
# 0                0.15                      0.09                       0.98
# 1                0.03                      0.02                       0.23
# 2                0.19                      0.19                       1.85
# 3                0.18                      0.04                       0.57
# 4                0.29                      0.11                       1.01

# %%
df_states = df_states.join(minimums.set_index(['fips'], verify_integrity=True ),on=['fips'], how='left')
df_states = df_states.join(maximums.set_index(['fips'], verify_integrity=True ),on=['fips'], how='left')

# %%
#calculate ratio of the current day's count divided by the 3-day average prior to current day
for i in range(0,df_states.shape[0]-1):
  if(df_states.iloc[i,5] == df_states.iloc[i+1,5]):
    if(df_states.iloc[i+1,9] != 0):
      df_states.loc[df_states.index[i],'count_ratio'] = np.round((df_states.iloc[i,9]/df_states.iloc[i+1,9]),2)
    else: 
      df_states.loc[df_states.index[i],'count_ratio'] = 0
    if(df_states.iloc[i+1,10] != 0):
      df_states.loc[df_states.index[i],'testing_capacity_ratio'] = np.round((df_states.iloc[i,10]/df_states.iloc[i+1,10]),2)
    else: 
      df_states.loc[df_states.index[i],'testing_capacity_ratio'] = 0
    if(df_states.iloc[i+1,11] != 0):
      df_states.loc[df_states.index[i],'mortality_ratio'] = np.round((df_states.iloc[i,11]/df_states.iloc[i+1,11]),2)
    else: 
      df_states.loc[df_states.index[i],'mortality_ratio'] = 0
    if(df_states.iloc[i+1,12] != 0):
      df_states.loc[df_states.index[i],'hospitalization_ratio'] = np.round((df_states.iloc[i,12]/df_states.iloc[i+1,12]),2)
    else: 
      df_states.loc[df_states.index[i],'hospitalization_ratio'] = 0
    if(df_states.iloc[i+1,13] != 0):
      df_states.loc[df_states.index[i],'infection_rate_ratio'] = np.round((df_states.iloc[i,13]/df_states.iloc[i+1,13]),2)
    else: 
      df_states.loc[df_states.index[i],'infection_rate_ratio'] = 0
    if(df_states.iloc[i+1,14] != 0):
      df_states.loc[df_states.index[i],'hospitalization_rate_ratio'] = np.round((df_states.iloc[i,14]/df_states.iloc[i+1,14]),2)
    else: 
      df_states.loc[df_states.index[i],'hospitalization_rate_ratio'] = 0
    if(df_states.iloc[i+1,15] != 0):
      df_states.loc[df_states.index[i],'hospitalization_rate2_ratio'] = np.round((df_states.iloc[i,15]/df_states.iloc[i+1,15]),2)
    else: 
      df_states.loc[df_states.index[i],'hospitalization_rate2_ratio'] = 0

# %%
df_states.head()
# Out:
#          date state  positive  hospitalizedCurrently   death  fips  \
# 1    20200814    AL  106309.0                 1376.0  1893.0     1
# 57   20200813    AL  105557.0                 1365.0  1890.0     1
# 113  20200812    AL  104786.0                 1372.0  1882.0     1
# 169  20200811    AL  103851.0                 1506.0  1847.0     1
# 225  20200810    AL  103020.0                 1528.0  1797.0     1
#
#      totalTestResults  TOTAL_NUM_LICENSED_BEDS  TOTAL_NUM_ICU_BEDS      count  \
# 1            824984.0                  18611.0              1637.0  105550.67
# 57           802562.0                  18611.0              1637.0  104731.33
# 113          795771.0                  18611.0              1637.0  103885.67
# 169          783689.0                  18611.0              1637.0  102735.00
# 225          780567.0                  18611.0              1637.0  100913.67
#
#      testing_capacity  mortality  hospitalization  infection_rate  \
# 1           807772.33    1888.33          1371.00            0.13
# 57          794007.33    1873.00          1414.33            0.13
# 113         786675.67    1842.00          1468.67            0.13
# 169         775569.00    1804.00          1543.00            0.13
# 225         764173.33    1766.67          1566.00            0.13
#
#      hospitalization_rate  hospitalization_rate2  count_min  \
# 1                    0.07                   0.84        0.0
# 57                   0.08                   0.86        0.0
# 113                  0.08                   0.90        0.0
# 169                  0.08                   0.94        0.0
# 225                  0.08                   0.96        0.0
#
#      testing_capacity_min  mortality_min  hospitalization_min  \
# 1                     0.0            0.0                  0.0
# 57                    0.0            0.0                  0.0
# 113                   0.0            0.0                  0.0
# 169                   0.0            0.0                  0.0
# 225                   0.0            0.0                  0.0
#
#      infection_rate_min  hospitalization_rate_min  hospitalization_rate2_min  \
# 1                  0.08                       0.0                       0.06
# 57                 0.08                       0.0                       0.06
# 113                0.08                       0.0                       0.06
# 169                0.08                       0.0                       0.06
# 225                0.08                       0.0                       0.06
#
#      count_max  testing_capacity_max  mortality_max  hospitalization_max  \
# 1    105550.67             807772.33        1888.33              1598.33
# 57   105550.67             807772.33        1888.33              1598.33
# 113  105550.67             807772.33        1888.33              1598.33
# 169  105550.67             807772.33        1888.33              1598.33
# 225  105550.67             807772.33        1888.33              1598.33
#
#      infection_rate_max  hospitalization_rate_max  hospitalization_rate2_max  \
# 1                  0.15                      0.09                       0.98
# 57                 0.15                      0.09                       0.98
# 113                0.15                      0.09                       0.98
# 169                0.15                      0.09                       0.98
# 225                0.15                      0.09                       0.98
#
#      count_ratio  testing_capacity_ratio  mortality_ratio  \
# 1           1.01                    1.02             1.01
# 57          1.01                    1.01             1.02
# 113         1.01                    1.01             1.02
# 169         1.02                    1.01             1.02
# 225         1.02                    1.01             1.01
#
#      hospitalization_ratio  infection_rate_ratio  hospitalization_rate_ratio  \
# 1                     0.97                   1.0                        0.88
# 57                    0.96                   1.0                        1.00
# 113                   0.95                   1.0                        1.00
# 169                   0.99                   1.0                        1.00
# 225                   0.99                   1.0                        1.00
#
#      hospitalization_rate2_ratio
# 1                           0.98
# 57                          0.96
# 113                         0.96
# 169                         0.98
# 225                         0.99

# %%
#calculate sub-indexes by normalizing the ratios
for i in range(0,df_states.shape[0]):
  if((df_states.iloc[i,23]-df_states.iloc[i,16]) != 0):
    df_states.loc[df_states.index[i],'count_subindex'] = np.round(((df_states.iloc[i,9] - df_states.iloc[i,16])/(df_states.iloc[i,23]-df_states.iloc[i,16])),2)
  else: 
    df_states.loc[df_states.index[i],'count_subindex'] = 0
  if((df_states.iloc[i,24]-df_states.iloc[i,17]) != 0):
    df_states.loc[df_states.index[i],'testing_capacity_subindex'] = np.round(((df_states.iloc[i,10] - df_states.iloc[i,17])/(df_states.iloc[i,24]-df_states.iloc[i,17])),2)
  else: 
    df_states.loc[df_states.index[i],'testing_capacity_subindex'] = 0
  if((df_states.iloc[i,25]-df_states.iloc[i,18]) != 0):
    df_states.loc[df_states.index[i],'mortality_subindex'] = np.round(((df_states.iloc[i,11] - df_states.iloc[i,18])/(df_states.iloc[i,25]-df_states.iloc[i,18])),2)
  else: 
    df_states.loc[df_states.index[i],'mortality_subindex'] = 0
  if((df_states.iloc[i,26]-df_states.iloc[i,19]) != 0):
    df_states.loc[df_states.index[i],'hospitalization_subindex'] = np.round(((df_states.iloc[i,12] - df_states.iloc[i,19])/(df_states.iloc[i,26]-df_states.iloc[i,19])),2)
  else: 
    df_states.loc[df_states.index[i],'hospitalization_subindex'] = 0
  if((df_states.iloc[i,27]-df_states.iloc[i,20]) != 0):
    df_states.loc[df_states.index[i],'infection_rate_subindex'] = np.round(((df_states.iloc[i,13] - df_states.iloc[i,20])/(df_states.iloc[i,27]-df_states.iloc[i,20])),2)
  else: 
    df_states.loc[df_states.index[i],'infection_rate_subindex'] = 0
  if((df_states.iloc[i,28]-df_states.iloc[i,21]) != 0):
    df_states.loc[df_states.index[i],'hospitalization_rate_subindex'] = np.round(((df_states.iloc[i,14] - df_states.iloc[i,21])/(df_states.iloc[i,28]-df_states.iloc[i,21])),2)
  else: 
    df_states.loc[df_states.index[i],'hospitalization_rate_subindex'] = 0
  if((df_states.iloc[i,29]-df_states.iloc[i,22]) != 0):
    df_states.loc[df_states.index[i],'hospitalization_rate2_subindex'] = np.round(((df_states.iloc[i,15] - df_states.iloc[i,22])/(df_states.iloc[i,29]-df_states.iloc[i,22])),2)
  else: 
    df_states.loc[df_states.index[i],'hospitalization_rate2_subindex'] = 0

# %%
df_states
# Out:
#           date state  positive  hospitalizedCurrently   death  fips  \
# 1     20200814    AL  106309.0                 1376.0  1893.0     1
# 57    20200813    AL  105557.0                 1365.0  1890.0     1
# 113   20200812    AL  104786.0                 1372.0  1882.0     1
# 169   20200811    AL  103851.0                 1506.0  1847.0     1
# 225   20200810    AL  103020.0                 1528.0  1797.0     1
# ...        ...   ...       ...                    ...     ...   ...
# 6594  20200419    PR    1213.0                  160.0    62.0    72
# 6650  20200418    PR    1118.0                  165.0    60.0    72
# 6994  20200412    VI      51.0                    3.0     1.0    78
# 7050  20200411    VI      51.0                    3.0     1.0    78
# 7106  20200410    VI      50.0                    3.0     1.0    78
#
#       totalTestResults  TOTAL_NUM_LICENSED_BEDS  TOTAL_NUM_ICU_BEDS  \
# 1             824984.0                  18611.0              1637.0
# 57            802562.0                  18611.0              1637.0
# 113           795771.0                  18611.0              1637.0
# 169           783689.0                  18611.0              1637.0
# 225           780567.0                  18611.0              1637.0
# ...                ...                      ...                 ...
# 6594            9493.0                   6976.0               814.0
# 6650            9173.0                   6976.0               814.0
# 6994             350.0                      NaN                 NaN
# 7050             350.0                      NaN                 NaN
# 7106             323.0                      NaN                 NaN
#
#           count  testing_capacity  mortality  hospitalization  infection_rate  \
# 1     105550.67         807772.33    1888.33          1371.00            0.13
# 57    104731.33         794007.33    1873.00          1414.33            0.13
# 113   103885.67         786675.67    1842.00          1468.67            0.13
# 169   102735.00         775569.00    1804.00          1543.00            0.13
# 225   100913.67         764173.33    1766.67          1566.00            0.13
# ...         ...               ...        ...              ...             ...
# 6594       0.00              0.00       0.00             0.00             NaN
# 6650       0.00              0.00       0.00             0.00             NaN
# 6994      50.67            341.00       1.00             3.00            0.15
# 7050        NaN               NaN        NaN              NaN             NaN
# 7106        NaN               NaN        NaN              NaN             NaN
#
#       hospitalization_rate  hospitalization_rate2  count_min  \
# 1                     0.07                   0.84       0.00
# 57                    0.08                   0.86       0.00
# 113                   0.08                   0.90       0.00
# 169                   0.08                   0.94       0.00
# 225                   0.08                   0.96       0.00
# ...                    ...                    ...        ...
# 6594                   NaN                    NaN       0.00
# 6650                   NaN                    NaN       0.00
# 6994                   NaN                    NaN      50.67
# 7050                   NaN                    NaN      50.67
# 7106                   NaN                    NaN      50.67
#
#       testing_capacity_min  mortality_min  hospitalization_min  \
# 1                      0.0            0.0                  0.0
# 57                     0.0            0.0                  0.0
# 113                    0.0            0.0                  0.0
# 169                    0.0            0.0                  0.0
# 225                    0.0            0.0                  0.0
# ...                    ...            ...                  ...
# 6594                   0.0            0.0                  0.0
# 6650                   0.0            0.0                  0.0
# 6994                 341.0            1.0                  3.0
# 7050                 341.0            1.0                  3.0
# 7106                 341.0            1.0                  3.0
#
#       infection_rate_min  hospitalization_rate_min  hospitalization_rate2_min  \
# 1                   0.08                      0.00                       0.06
# 57                  0.08                      0.00                       0.06
# 113                 0.08                      0.00                       0.06
# 169                 0.08                      0.00                       0.06
# 225                 0.08                      0.00                       0.06
# ...                  ...                       ...                        ...
# 6594                0.03                      0.01                       0.09
# 6650                0.03                      0.01                       0.09
# 6994                0.15                      0.00                       0.00
# 7050                0.15                      0.00                       0.00
# 7106                0.15                      0.00                       0.00
#
#       count_max  testing_capacity_max  mortality_max  hospitalization_max  \
# 1     105550.67             807772.33        1888.33              1598.33
# 57    105550.67             807772.33        1888.33              1598.33
# 113   105550.67             807772.33        1888.33              1598.33
# 169   105550.67             807772.33        1888.33              1598.33
# 225   105550.67             807772.33        1888.33              1598.33
# ...         ...                   ...            ...                  ...
# 6594   24549.33             330521.33         306.00               516.33
# 6650   24549.33             330521.33         306.00               516.33
# 6994      50.67                341.00           1.00                 3.00
# 7050      50.67                341.00           1.00                 3.00
# 7106      50.67                341.00           1.00                 3.00
#
#       infection_rate_max  hospitalization_rate_max  hospitalization_rate2_max  \
# 1                   0.15                      0.09                       0.98
# 57                  0.15                      0.09                       0.98
# 113                 0.15                      0.09                       0.98
# 169                 0.15                      0.09                       0.98
# 225                 0.15                      0.09                       0.98
# ...                  ...                       ...                        ...
# 6594                1.00                      0.07                       0.63
# 6650                1.00                      0.07                       0.63
# 6994                0.15                      0.00                       0.00
# 7050                0.15                      0.00                       0.00
# 7106                0.15                      0.00                       0.00
#
#       count_ratio  testing_capacity_ratio  mortality_ratio  \
# 1            1.01                    1.02             1.01
# 57           1.01                    1.01             1.02
# 113          1.01                    1.01             1.02
# 169          1.02                    1.01             1.02
# 225          1.02                    1.01             1.01
# ...           ...                     ...              ...
# 6594         0.00                    0.00             0.00
# 6650          NaN                     NaN              NaN
# 6994          NaN                     NaN              NaN
# 7050          NaN                     NaN              NaN
# 7106          NaN                     NaN              NaN
#
#       hospitalization_ratio  infection_rate_ratio  hospitalization_rate_ratio  \
# 1                      0.97                   1.0                        0.88
# 57                     0.96                   1.0                        1.00
# 113                    0.95                   1.0                        1.00
# 169                    0.99                   1.0                        1.00
# 225                    0.99                   1.0                        1.00
# ...                     ...                   ...                         ...
# 6594                   0.00                   NaN                         NaN
# 6650                    NaN                   NaN                         NaN
# 6994                    NaN                   NaN                         NaN
# 7050                    NaN                   NaN                         NaN
# 7106                    NaN                   NaN                         NaN
#
#       hospitalization_rate2_ratio  count_subindex  testing_capacity_subindex  \
# 1                            0.98            1.00                       1.00
# 57                           0.96            0.99                       0.98
# 113                          0.96            0.98                       0.97
# 169                          0.98            0.97                       0.96
# 225                          0.99            0.96                       0.95
# ...                           ...             ...                        ...
# 6594                          NaN            0.00                       0.00
# 6650                          NaN            0.00                       0.00
# 6994                          NaN            0.00                       0.00
# 7050                          NaN            0.00                       0.00
# 7106                          NaN            0.00                       0.00
#
#       mortality_subindex  hospitalization_subindex  infection_rate_subindex  \
# 1                   1.00                      0.86                     0.71
# 57                  0.99                      0.88                     0.71
# 113                 0.98                      0.92                     0.71
# 169                 0.96                      0.97                     0.71
# 225                 0.94                      0.98                     0.71
# ...                  ...                       ...                      ...
# 6594                0.00                      0.00                      NaN
# 6650                0.00                      0.00                      NaN
# 6994                0.00                      0.00                     0.00
# 7050                0.00                      0.00                     0.00
# 7106                0.00                      0.00                     0.00
#
#       hospitalization_rate_subindex  hospitalization_rate2_subindex
# 1                              0.78                            0.85
# 57                             0.89                            0.87
# 113                            0.89                            0.91
# 169                            0.89                            0.96
# 225                            0.89                            0.98
# ...                             ...                             ...
# 6594                            NaN                             NaN
# 6650                            NaN                             NaN
# 6994                           0.00                            0.00
# 7050                           0.00                            0.00
# 7106                           0.00                            0.00
#
# [6461 rows x 44 columns]

# %%
#calculate composite index by taking arthimetic mean the sub-indexes
cols = ['count_subindex', 'testing_capacity_subindex', 'mortality_subindex',
    'hospitalization_subindex','infection_rate_subindex','hospitalization_rate_subindex',
                                  'hospitalization_rate2_subindex']
df_states['comp_index'] = df_states[cols].astype(float).mean(axis=1)

# %%
#test comp index 
# split data into train test set into train and test in 70:30 ratio
df = df_states

# drop records without composite index
df = df.dropna()

y = df["comp_index"]
X = df.drop(['comp_index','state','TOTAL_NUM_LICENSED_BEDS','TOTAL_NUM_ICU_BEDS','date','fips'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# %%
# Train and predict using linear regression
linear_reg = LinearRegression()
# Train with the train dataset
linear_reg.fit(X_train, y_train)
coeff_df = pd.DataFrame(linear_reg.coef_, X_train.columns, columns=['Coefficient'])  
coeff_df
# Out:
#                                  Coefficient
# positive                        2.631714e-16
# hospitalizedCurrently           1.441924e-15
# death                           1.034371e-14
# totalTestResults               -1.068131e-18
# count                          -3.374361e-16
# testing_capacity                6.985123e-18
# mortality                      -9.399149e-15
# hospitalization                 3.648774e-15
# infection_rate                  9.898560e-11
# hospitalization_rate           -2.757728e-10
# hospitalization_rate2          -7.204319e-12
# count_min                      -1.412195e-11
# testing_capacity_min           -6.007417e-13
# mortality_min                   6.788181e-13
# hospitalization_min            -5.705436e-13
# infection_rate_min              7.470955e-11
# hospitalization_rate_min        2.820367e-10
# hospitalization_rate2_min      -2.556991e-11
# count_max                      -8.128661e-18
# testing_capacity_max           -3.451250e-18
# mortality_max                   6.740108e-16
# hospitalization_max             3.415103e-16
# infection_rate_max             -1.161189e-12
# hospitalization_rate_max       -4.901085e-12
# hospitalization_rate2_max      -4.056144e-12
# count_ratio                    -1.017993e-11
# testing_capacity_ratio          3.935425e-12
# mortality_ratio                -3.623992e-12
# hospitalization_ratio          -1.303280e-12
# infection_rate_ratio            9.587199e-13
# hospitalization_rate_ratio     -1.228087e-14
# hospitalization_rate2_ratio    -2.473298e-12
# count_subindex                  1.428571e-01
# testing_capacity_subindex       1.428571e-01
# mortality_subindex              1.428571e-01
# hospitalization_subindex        1.428571e-01
# infection_rate_subindex         1.428571e-01
# hospitalization_rate_subindex   1.428571e-01
# hospitalization_rate2_subindex  1.428571e-01

# %%
y_pred = linear_reg.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)
df1
# Out:
#         Actual  Predicted
# 3295  0.200000   0.200000
# 5048  0.681429   0.681429
# 2844  0.357143   0.357143
# 4351  0.174286   0.174286
# 3127  0.235714   0.235714
# 7327  0.091429   0.091429
# 6344  0.604286   0.604286
# 4964  0.292857   0.292857
# 4509  0.075714   0.075714
# 7351  0.214286   0.214286
# 206   0.718571   0.718571
# 4359  0.134286   0.134286
# 4643  0.438571   0.438571
# 524   0.677143   0.677143
# 532   0.911429   0.911429
# 3996  0.262857   0.262857
# 734   0.495714   0.495714
# 5039  0.258571   0.258571
# 690   0.922857   0.922857
# 6041  0.591429   0.591429
# 6081  0.584286   0.584286
# 4569  0.625714   0.625714
# 5490  0.127143   0.127143
# 6494  0.411429   0.411429
# 1153  0.475714   0.475714

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 5.580449783423377e-12
# Mean Squared Error: 7.651639878577852e-23
# Root Mean Squared Error: 8.747365248220662e-12

# %%
#New Jersey
df_states.loc[df_states['fips'] == 34].head()
# Out:
#          date state  positive  hospitalizedCurrently    death  fips  \
# 34   20200814    NJ  187164.0                  514.0  15903.0    34
# 90   20200813    NJ  186594.0                  545.0  15893.0    34
# 146  20200812    NJ  185938.0                  592.0  15885.0    34
# 202  20200811    NJ  185475.0                  538.0  15890.0    34
# 258  20200810    NJ  185031.0                  545.0  15878.0    34
#
#      totalTestResults  TOTAL_NUM_LICENSED_BEDS  TOTAL_NUM_ICU_BEDS      count  \
# 34          2429841.0                  26464.0              1758.0  186565.33
# 90          2403690.0                  26464.0              1758.0  186002.33
# 146         2376016.0                  26464.0              1758.0  185481.33
# 202         2350310.0                  26464.0              1758.0  185093.00
# 258         2324046.0                  26464.0              1758.0  184744.33
#
#      testing_capacity  mortality  hospitalization  infection_rate  \
# 34         2403182.33   15893.67           550.33            0.08
# 90         2376672.00   15889.33           558.33            0.08
# 146        2350124.00   15884.33           558.33            0.08
# 202        2325402.67   15880.67           522.00            0.08
# 258        2292896.67   15873.67           522.67            0.08
#
#      hospitalization_rate  hospitalization_rate2  count_min  \
# 34                   0.02                   0.31        0.0
# 90                   0.02                   0.32        0.0
# 146                  0.02                   0.32        0.0
# 202                  0.02                   0.30        0.0
# 258                  0.02                   0.30        0.0
#
#      testing_capacity_min  mortality_min  hospitalization_min  \
# 34                    0.0            0.0                  0.0
# 90                    0.0            0.0                  0.0
# 146                   0.0            0.0                  0.0
# 202                   0.0            0.0                  0.0
# 258                   0.0            0.0                  0.0
#
#      infection_rate_min  hospitalization_rate_min  hospitalization_rate2_min  \
# 34                 0.08                      0.02                        0.3
# 90                 0.08                      0.02                        0.3
# 146                0.08                      0.02                        0.3
# 202                0.08                      0.02                        0.3
# 258                0.08                      0.02                        0.3
#
#      count_max  testing_capacity_max  mortality_max  hospitalization_max  \
# 34   186565.33            2403182.33       15893.67              8226.33
# 90   186565.33            2403182.33       15893.67              8226.33
# 146  186565.33            2403182.33       15893.67              8226.33
# 202  186565.33            2403182.33       15893.67              8226.33
# 258  186565.33            2403182.33       15893.67              8226.33
#
#      infection_rate_max  hospitalization_rate_max  hospitalization_rate2_max  \
# 34                  0.5                      0.31                       4.68
# 90                  0.5                      0.31                       4.68
# 146                 0.5                      0.31                       4.68
# 202                 0.5                      0.31                       4.68
# 258                 0.5                      0.31                       4.68
#
#      count_ratio  testing_capacity_ratio  mortality_ratio  \
# 34           1.0                    1.01              1.0
# 90           1.0                    1.01              1.0
# 146          1.0                    1.01              1.0
# 202          1.0                    1.01              1.0
# 258          1.0                    1.01              1.0
#
#      hospitalization_ratio  infection_rate_ratio  hospitalization_rate_ratio  \
# 34                    0.99                   1.0                         1.0
# 90                    1.00                   1.0                         1.0
# 146                   1.07                   1.0                         1.0
# 202                   1.00                   1.0                         1.0
# 258                   1.00                   1.0                         1.0
#
#      hospitalization_rate2_ratio  count_subindex  testing_capacity_subindex  \
# 34                          0.97            1.00                       1.00
# 90                          1.00            1.00                       0.99
# 146                         1.07            0.99                       0.98
# 202                         1.00            0.99                       0.97
# 258                         1.00            0.99                       0.95
#
#      mortality_subindex  hospitalization_subindex  infection_rate_subindex  \
# 34                  1.0                      0.07                      0.0
# 90                  1.0                      0.07                      0.0
# 146                 1.0                      0.07                      0.0
# 202                 1.0                      0.06                      0.0
# 258                 1.0                      0.06                      0.0
#
#      hospitalization_rate_subindex  hospitalization_rate2_subindex  comp_index
# 34                             0.0                             0.0    0.438571
# 90                             0.0                             0.0    0.437143
# 146                            0.0                             0.0    0.434286
# 202                            0.0                             0.0    0.431429
# 258                            0.0                             0.0    0.428571

# %%
#Alaska
df_states.loc[df_states['fips'] == 2].head()
# Out:
#          date state  positive  hospitalizedCurrently  death  fips  \
# 0    20200814    AK    4869.0                   38.0   27.0     2
# 56   20200813    AK    4750.0                   46.0   27.0     2
# 112  20200812    AK    4655.0                   39.0   27.0     2
# 168  20200811    AK    4589.0                   39.0   26.0     2
# 224  20200810    AK    4539.0                   37.0   26.0     2
#
#      totalTestResults  TOTAL_NUM_LICENSED_BEDS  TOTAL_NUM_ICU_BEDS    count  \
# 0            295929.0                   1832.0               193.0  4758.00
# 56           294053.0                   1832.0               193.0  4664.67
# 112          292582.0                   1832.0               193.0  4594.33
# 168          290744.0                   1832.0               193.0  4533.67
# 224          280343.0                   1832.0               193.0  4461.67
#
#      testing_capacity  mortality  hospitalization  infection_rate  \
# 0           294188.00      27.00            41.00            0.02
# 56          292459.67      26.67            41.33            0.02
# 112         287889.67      26.33            38.33            0.02
# 168         283002.00      26.00            38.67            0.02
# 224         277285.00      26.00            38.00            0.02
#
#      hospitalization_rate  hospitalization_rate2  count_min  \
# 0                    0.02                   0.21        0.0
# 56                   0.02                   0.21        0.0
# 112                  0.02                   0.20        0.0
# 168                  0.02                   0.20        0.0
# 224                  0.02                   0.20        0.0
#
#      testing_capacity_min  mortality_min  hospitalization_min  \
# 0                     0.0            0.0                  0.0
# 56                    0.0            0.0                  0.0
# 112                   0.0            0.0                  0.0
# 168                   0.0            0.0                  0.0
# 224                   0.0            0.0                  0.0
#
#      infection_rate_min  hospitalization_rate_min  hospitalization_rate2_min  \
# 0                  0.01                       0.0                       0.04
# 56                 0.01                       0.0                       0.04
# 112                0.01                       0.0                       0.04
# 168                0.01                       0.0                       0.04
# 224                0.01                       0.0                       0.04
#
#      count_max  testing_capacity_max  mortality_max  hospitalization_max  \
# 0       4758.0              294188.0           27.0                44.67
# 56      4758.0              294188.0           27.0                44.67
# 112     4758.0              294188.0           27.0                44.67
# 168     4758.0              294188.0           27.0                44.67
# 224     4758.0              294188.0           27.0                44.67
#
#      infection_rate_max  hospitalization_rate_max  hospitalization_rate2_max  \
# 0                  0.03                      0.02                       0.23
# 56                 0.03                      0.02                       0.23
# 112                0.03                      0.02                       0.23
# 168                0.03                      0.02                       0.23
# 224                0.03                      0.02                       0.23
#
#      count_ratio  testing_capacity_ratio  mortality_ratio  \
# 0           1.02                    1.01             1.01
# 56          1.02                    1.02             1.01
# 112         1.01                    1.02             1.01
# 168         1.02                    1.02             1.00
# 224         1.02                    1.01             1.01
#
#      hospitalization_ratio  infection_rate_ratio  hospitalization_rate_ratio  \
# 0                     0.99                   1.0                         1.0
# 56                    1.08                   1.0                         1.0
# 112                   0.99                   1.0                         1.0
# 168                   1.02                   1.0                         1.0
# 224                   1.00                   1.0                         1.0
#
#      hospitalization_rate2_ratio  count_subindex  testing_capacity_subindex  \
# 0                           1.00            1.00                       1.00
# 56                          1.05            0.98                       0.99
# 112                         1.00            0.97                       0.98
# 168                         1.00            0.95                       0.96
# 224                         1.00            0.94                       0.94
#
#      mortality_subindex  hospitalization_subindex  infection_rate_subindex  \
# 0                  1.00                      0.92                      0.5
# 56                 0.99                      0.93                      0.5
# 112                0.98                      0.86                      0.5
# 168                0.96                      0.87                      0.5
# 224                0.96                      0.85                      0.5
#
#      hospitalization_rate_subindex  hospitalization_rate2_subindex  comp_index
# 0                              1.0                            0.89    0.901429
# 56                             1.0                            0.89    0.897143
# 112                            1.0                            0.84    0.875714
# 168                            1.0                            0.84    0.868571
# 224                            1.0                            0.84    0.861429

# %%
#Washington
df_states.loc[df_states['fips'] == 53].head()
# Out:
#          date state  positive  hospitalizedCurrently   death  fips  \
# 52   20200814    WA   65339.0                  403.0  1736.0    53
# 108  20200813    WA   64702.0                  395.0  1724.0    53
# 164  20200812    WA   64151.0                  383.0  1716.0    53
# 220  20200811    WA   63647.0                  386.0  1697.0    53
# 276  20200810    WA   63072.0                  402.0  1688.0    53
#
#      totalTestResults  TOTAL_NUM_LICENSED_BEDS  TOTAL_NUM_ICU_BEDS     count  \
# 52          1015446.0                  17736.0              1685.0  64730.67
# 108         1014809.0                  17736.0              1685.0  64166.67
# 164         1014258.0                  17736.0              1685.0  63623.33
# 220         1013754.0                  17736.0              1685.0  63080.67
# 276         1013179.0                  17736.0              1685.0  62394.00
#
#      testing_capacity  mortality  hospitalization  infection_rate  \
# 52         1014837.67    1725.33           393.67            0.06
# 108        1014273.67    1712.33           388.00            0.06
# 164        1013730.33    1700.33           390.33            0.06
# 220        1013187.67    1691.00           396.00            0.06
# 276        1012501.00    1682.67           405.67            0.06
#
#      hospitalization_rate  hospitalization_rate2  count_min  \
# 52                   0.02                   0.23        0.0
# 108                  0.02                   0.23        0.0
# 164                  0.02                   0.23        0.0
# 220                  0.02                   0.24        0.0
# 276                  0.02                   0.24        0.0
#
#      testing_capacity_min  mortality_min  hospitalization_min  \
# 52                    0.0            0.0                  0.0
# 108                   0.0            0.0                  0.0
# 164                   0.0            0.0                  0.0
# 220                   0.0            0.0                  0.0
# 276                   0.0            0.0                  0.0
#
#      infection_rate_min  hospitalization_rate_min  hospitalization_rate2_min  \
# 52                 0.06                      0.01                        0.1
# 108                0.06                      0.01                        0.1
# 164                0.06                      0.01                        0.1
# 220                0.06                      0.01                        0.1
# 276                0.06                      0.01                        0.1
#
#      count_max  testing_capacity_max  mortality_max  hospitalization_max  \
# 52    64730.67            1014837.67        1725.33                649.0
# 108   64730.67            1014837.67        1725.33                649.0
# 164   64730.67            1014837.67        1725.33                649.0
# 220   64730.67            1014837.67        1725.33                649.0
# 276   64730.67            1014837.67        1725.33                649.0
#
#      infection_rate_max  hospitalization_rate_max  hospitalization_rate2_max  \
# 52                 0.09                      0.04                       0.39
# 108                0.09                      0.04                       0.39
# 164                0.09                      0.04                       0.39
# 220                0.09                      0.04                       0.39
# 276                0.09                      0.04                       0.39
#
#      count_ratio  testing_capacity_ratio  mortality_ratio  \
# 52          1.01                     1.0             1.01
# 108         1.01                     1.0             1.01
# 164         1.01                     1.0             1.01
# 220         1.01                     1.0             1.00
# 276         1.01                     1.0             1.01
#
#      hospitalization_ratio  infection_rate_ratio  hospitalization_rate_ratio  \
# 52                    1.01                   1.0                         1.0
# 108                   0.99                   1.0                         1.0
# 164                   0.99                   1.0                         1.0
# 220                   0.98                   1.0                         1.0
# 276                   1.00                   1.0                         1.0
#
#      hospitalization_rate2_ratio  count_subindex  testing_capacity_subindex  \
# 52                          1.00            1.00                        1.0
# 108                         1.00            0.99                        1.0
# 164                         0.96            0.98                        1.0
# 220                         1.00            0.97                        1.0
# 276                         1.00            0.96                        1.0
#
#      mortality_subindex  hospitalization_subindex  infection_rate_subindex  \
# 52                 1.00                      0.61                      0.0
# 108                0.99                      0.60                      0.0
# 164                0.99                      0.60                      0.0
# 220                0.98                      0.61                      0.0
# 276                0.98                      0.63                      0.0
#
#      hospitalization_rate_subindex  hospitalization_rate2_subindex  comp_index
# 52                            0.33                            0.45    0.627143
# 108                           0.33                            0.45    0.622857
# 164                           0.33                            0.45    0.621429
# 220                           0.33                            0.48    0.624286
# 276                           0.33                            0.48    0.625714

# %%
#District of Columbia
df_states.loc[df_states['fips'] == 11].head()
# Out:
#          date state  positive  hospitalizedCurrently  death  fips  \
# 8    20200814    DC   13118.0                   84.0  594.0    11
# 64   20200813    DC   13024.0                   83.0  594.0    11
# 120  20200812    DC   12959.0                   85.0  593.0    11
# 176  20200811    DC   12896.0                   83.0  593.0    11
# 232  20200810    DC   12807.0                   75.0  591.0    11
#
#      totalTestResults  TOTAL_NUM_LICENSED_BEDS  TOTAL_NUM_ICU_BEDS     count  \
# 8            236305.0                   4262.0               407.0  13033.67
# 64           229649.0                   4262.0               407.0  12959.67
# 120          226741.0                   4262.0               407.0  12887.33
# 176          224749.0                   4262.0               407.0  12818.67
# 232          220391.0                   4262.0               407.0  12737.67
#
#      testing_capacity  mortality  hospitalization  infection_rate  \
# 8           230898.33     593.67            84.00            0.06
# 64          227046.33     593.33            83.67            0.06
# 120         223960.33     592.33            81.00            0.06
# 176         221027.33     591.67            78.33            0.06
# 232         217222.33     590.67            77.33            0.06
#
#      hospitalization_rate  hospitalization_rate2  count_min  \
# 8                    0.02                   0.21        0.0
# 64                   0.02                   0.21        0.0
# 120                  0.02                   0.20        0.0
# 176                  0.02                   0.19        0.0
# 232                  0.02                   0.19        0.0
#
#      testing_capacity_min  mortality_min  hospitalization_min  \
# 8                     0.0            0.0                  0.0
# 64                    0.0            0.0                  0.0
# 120                   0.0            0.0                  0.0
# 176                   0.0            0.0                  0.0
# 232                   0.0            0.0                  0.0
#
#      infection_rate_min  hospitalization_rate_min  hospitalization_rate2_min  \
# 8                  0.06                      0.02                       0.19
# 64                 0.06                      0.02                       0.19
# 120                0.06                      0.02                       0.19
# 176                0.06                      0.02                       0.19
# 232                0.06                      0.02                       0.19
#
#      count_max  testing_capacity_max  mortality_max  hospitalization_max  \
# 8     13033.67             230898.33         593.67                447.0
# 64    13033.67             230898.33         593.67                447.0
# 120   13033.67             230898.33         593.67                447.0
# 176   13033.67             230898.33         593.67                447.0
# 232   13033.67             230898.33         593.67                447.0
#
#      infection_rate_max  hospitalization_rate_max  hospitalization_rate2_max  \
# 8                  0.22                       0.1                        1.1
# 64                 0.22                       0.1                        1.1
# 120                0.22                       0.1                        1.1
# 176                0.22                       0.1                        1.1
# 232                0.22                       0.1                        1.1
#
#      count_ratio  testing_capacity_ratio  mortality_ratio  \
# 8           1.01                    1.02              1.0
# 64          1.01                    1.01              1.0
# 120         1.01                    1.01              1.0
# 176         1.01                    1.02              1.0
# 232         1.01                    1.02              1.0
#
#      hospitalization_ratio  infection_rate_ratio  hospitalization_rate_ratio  \
# 8                     1.00                   1.0                         1.0
# 64                    1.03                   1.0                         1.0
# 120                   1.03                   1.0                         1.0
# 176                   1.01                   1.0                         1.0
# 232                   0.94                   1.0                         1.0
#
#      hospitalization_rate2_ratio  count_subindex  testing_capacity_subindex  \
# 8                           1.00            1.00                       1.00
# 64                          1.05            0.99                       0.98
# 120                         1.05            0.99                       0.97
# 176                         1.00            0.98                       0.96
# 232                         0.95            0.98                       0.94
#
#      mortality_subindex  hospitalization_subindex  infection_rate_subindex  \
# 8                  1.00                      0.19                      0.0
# 64                 1.00                      0.19                      0.0
# 120                1.00                      0.18                      0.0
# 176                1.00                      0.18                      0.0
# 232                0.99                      0.17                      0.0
#
#      hospitalization_rate_subindex  hospitalization_rate2_subindex  comp_index
# 8                              0.0                            0.02    0.458571
# 64                             0.0                            0.02    0.454286
# 120                            0.0                            0.01    0.450000
# 176                            0.0                            0.00    0.445714
# 232                            0.0                            0.00    0.440000
